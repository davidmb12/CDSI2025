# %% [markdown]
# <h1>Reconocimiento de audio</h1>

# %% [markdown]
# <b>Disclaimer: Este notebook utiliza funciones que estan definidos en distintos archivos .py que estan incluidos en la carpeta del proyecto <b>

# %% [markdown]
# <h2>Importacion de librerias necesarias</h2>

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score
from tensorflow.keras.regularizers import l2
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler
from sklearn.svm import SVC
from imblearn.over_sampling import SMOTE

from audioLoading import loadAudios
from scipy.io import wavfile
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt, IPython.display as ipd
import librosa, librosa.display
from convertFiles import convertFiles
from pathlib import Path
from scipy.io import wavfile

# %% [markdown]
# Cargar los audios

# %%
audios = loadAudios(f"./AUDIO/All-Audios/Metodo-01/*")
audios_features = []

# %%
print(audios)
# Out:
# [[(array([ 3.6994724e-08, -3.4451723e-08, -8.4974126e-08, ...,
#        -3.0796460e-03, -3.2176557e-03, -1.3028292e-03], dtype=float32), 22050), 'AdriaM-01_1.mp3'], [(array([ 2.1867706e-07,  6.4148921e-08, -6.7088997e-08, ...,
#        -1.1476648e-05, -7.3682866e-05, -4.4857698e-05], dtype=float32), 22050), 'AdriaM-01_2.mp3'], [(array([-5.5615430e-07, -4.9057905e-07, -2.7166962e-07, ...,
#        -9.6194190e-04, -6.2536699e-04, -1.9251645e-04], dtype=float32), 22050), 'AdriaM-01_3.mp3'], [(array([-1.2725468e-08, -1.4755234e-08, -2.2014088e-08, ...,
#         1.3737469e-03,  1.1738316e-03,  4.3994794e-04], dtype=float32), 22050), 'AdriaM-01_4.mp3'], [(array([ 2.8007176e-07,  3.5355225e-07,  4.5377217e-07, ...,
#        -2.1950693e-03, -2.0250727e-03, -7.7857112e-04], dtype=float32), 22050), 'AdriaM-01_5.mp3'], [(array([ 0.        ,  0.        ,  0.        , ..., -0.01676467,
# ...

# %% [markdown]
# Extraccion de caracteristicas

# %%
audios_features = []
labels =[]
for audio_signal,filename in audios:
    features = [
        np.mean(librosa.feature.mfcc(y=audio_signal[0], sr=audio_signal[1], n_mfcc=13), axis=1)[0],
        np.var(librosa.feature.mfcc(y=audio_signal[0], sr=audio_signal[1], n_mfcc=13), axis=1)[0],
        np.mean(librosa.feature.spectral_contrast(y=audio_signal[0],sr=audio_signal[1],n_fft=256)[0,0]),
        np.mean(librosa.feature.spectral_centroid(y=audio_signal[0],sr=audio_signal[1])[0,0]),
        np.mean(librosa.feature.chroma_stft(y=audio_signal[0],sr=audio_signal[1])[0,0]),
        np.mean(librosa.feature.zero_crossing_rate(y=audio_signal[0])[0,0]),
        np.mean(librosa.feature.rms(y=audio_signal[0])[0,0]),
        np.mean(librosa.yin(y=audio_signal[0], fmin=80, fmax=300))
    ]
    labels.append(str.split(filename,'-')[0])
    audios_features.append(features)

# %%
print(audios_features)
# Out:
# [[-411.9387, 9538.124, 0.625955383653789, 1746.3162351750789, 0.62142605, 0.0810546875, 0.00096060475, 144.70402489548212], [-430.55234, 9544.218, 0.21866992437173138, 1439.8753480485013, 0.91188693, 0.06689453125, 0.00086317235, 157.89320636427888], [-442.82272, 10698.198, 0.9886520281228997, 1618.9203684986578, 0.8487246, 0.07080078125, 0.00063794665, 187.49990344748582], [-439.56573, 10643.199, 4.42314336232689, 1125.735173309063, 0.73967844, 0.0439453125, 0.0006119123, 156.38159987097814], [-434.2387, 10952.674, 2.750751652100199, 1673.1081172971747, 0.49196237, 0.0693359375, 0.0007782843, 148.31441158238584], [-464.50436, 8033.1123, 2.8715621855186555, 0.0, 0.0, 0.0, 0.0, 202.91269781529783], [-448.85046, 9951.235, 1.2017160894977366, 0.0, 0.0, 0.0, 0.0, 205.2886955124856], [-424.30182, 10682.878, 2.142363906783885, 0.0, 0.0, 0.0, 0.0, 216.92185295420293], [-442.50983, 9226.267, 5.016694421502962, 0.0, 0.0, 0.0, 0.0, 200.442959062208], [-461.77283, 13615.611, 1.8798156420023417,
# ...

# %% [markdown]
# Crear el DataFrame

# %%
df = pd.DataFrame(audios_features,columns=["mfcc_mean","mfcc_var","spectral_contrast","spectral_centroid","chroma_stft","zero_crossing_rate","rms","f0"])
df["Label"]=labels
df = df[["Label"]+list(df.columns[:-1])]
df.to_csv("audio_features.csv",index=False)

# %% [markdown]
# Establecer X y Y

# %%
x = df[["mfcc_mean","mfcc_var","spectral_contrast","spectral_centroid","chroma_stft","zero_crossing_rate","rms","f0"]]
y = df["Label"]

# %% [markdown]
# Normalizar datos (Usando Standard Scaler)

# %%
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %%
pca = PCA(n_components=.5)
x_pca=pca.fit_transform(x_scaled)

df_pca=pd.DataFrame(x_pca)
print(x_pca)
# Out:
# [[ 0.56937251 -0.36690435 -0.34844422]
#  [ 0.73082476 -0.39022893 -0.38790796]
#  [ 0.58888803 -0.06486836 -0.8219393 ]
#  ...
#  [-0.20121875  0.36205397 -0.72865527]
#  [-0.06537234  0.1238702  -0.22152372]
#  [-0.07821436  0.77691315 -0.28930595]]

# %%
x_train,x_test,y_train,y_test = train_test_split(x_scaled,y,test_size = 0.2, random_state=1)

# %% [markdown]
# Crear y entrenar el modelo

# %%
clf = DecisionTreeClassifier()
clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
accuracy = clf.score(x_test,y_test)
print(accuracy)
# Out:
# 0.3089430894308943

# %%
cv_scores = cross_val_score(clf,x,y,cv=5)

# %%
print(cv_scores)
# Out:
# [0.28455285 0.42276423 0.36585366 0.33333333 0.35772358]

# %% [markdown]
# Crear y entrenar el modelo (Random Forest)

# %%
model = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=42)
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=10, random_state=42)

# %%
y_pred = model.predict(x_test)
accuracy = accuracy_score(y_test,y_pred)
print(accuracy)
# Out:
# 0.4065040650406504
